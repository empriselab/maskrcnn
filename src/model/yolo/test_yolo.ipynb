# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['../data/training/v1/bag_1/bag_1_callback_50_img.png']  # batch of images

# Inference
results = model(imgs)

# Results
results.print()
results.show()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tie
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# /home/emprise/.local/lib/python3.8/site-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/emprise/.cache/torch/hub/master.zip
# /home/emprise/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# requirements: YOLOv5 requirements "gitpython>=3.1.30" "matplotlib>=3.2.2" "setuptools>=65.5.1" not found, attempting AutoUpdate...
# ERROR: launchpadlib 1.10.13 requires testresources, which is not installed.
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.7.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
# Collecting setuptools>=65.5.1
#   Downloading setuptools-67.6.1-py3-none-any.whl (1.1 MB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/emprise/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2) (5.10.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2) (20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/emprise/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: numpy>=1.20 in /home/emprise/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2) (1.24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/emprise/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2) (9.4.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/emprise/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.2.2) (3.11.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2) (1.14.0)
# Installing collected packages: smmap, gitdb, gitpython, contourpy, fonttools, matplotlib, setuptools
# Successfully installed contourpy-1.0.7 fonttools-4.39.3 gitdb-4.0.10 gitpython-3.1.31 matplotlib-3.7.1 setuptools-67.6.1 smmap-5.0.0
#
# requirements: 3 packages updated per /home/emprise/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2023-4-7 Python-3.8.10 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24245MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 31.0MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 720x1280 2 knifes, 2 carrots, 1 dining table
# Speed: 84.5ms pre-process, 623.2ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1280x720>
#          xmin        ymin         xmax        ymax  confidence  class  \
# 0  740.391541  168.679749   797.616028  235.619080    0.669920     51
# 1  692.328552  331.886353   770.585632  400.463867    0.574136     51
# 2  388.615082   88.076721   465.267059  392.238037    0.561458     43
# 3  472.378357  446.779724   768.331726  529.424255    0.494533     43
# 4    5.528137    0.000000  1167.904785  716.950378    0.258552     60
#
#            name
# 0        carrot
# 1        carrot
# 2         knife
# 3         knife
# 4  dining table
